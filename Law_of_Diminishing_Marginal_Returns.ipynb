# %% [markdown]
# <center><h1 style="background-color: #C6F3CD; border-radius: 10px; color: #FFFFFF; padding: 5px;">
# Law of Diminishing Marginal Returns
# </h1><center/>

# %% [markdown]
# **Link to the article** : https://medium.com/@soulawalid/law-of-diminishing-marginal-returns-cf9a7da371aa?sk=be2f3ac461d0da03246bbda2bf89ae2f

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Data
workers = [1, 2, 3, 4, 5, 6]
total_output = [10, 22, 32, 38, 41, 42]

# Calculate marginal output
marginal_output = [total_output[0]] + [
    total_output[i] - total_output[i-1] for i in range(1, len(total_output))
]

# Plotting
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(workers, total_output, marker='o')
plt.title("Total Output vs Workers")
plt.xlabel("Number of Workers")
plt.ylabel("Total Output")

plt.subplot(1, 2, 2)
plt.plot(workers, marginal_output, marker='o', color='orange')
plt.title("Marginal Output vs Workers")
plt.xlabel("Number of Workers")
plt.ylabel("Marginal Output")

plt.tight_layout()
plt.show()

# %%
df = pd.DataFrame({
    'Workers': workers,
    'Total Output': total_output,
    'Marginal Output': marginal_output
})

df
# Out:
#    Workers  Total Output  Marginal Output
# 0        1            10               10
# 1        2            22               12
# 2        3            32               10
# 3        4            38                6
# 4        5            41                3
# 5        6            42                1
